# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
df=pd.read_json('/content/drive/MyDrive/Irwin data analysis portfolio/data/data/cities.json')

#What are the mean and median populations for these 1,000 largest cities? What does that tell you?
#df['average_population']=df['population'].mean() #here we are trying to find the average population and make it appear in the dataframe
#df['median_population']=df['population'].median()#here are trying to find the median population and make it appear in the dataframe
#df['comparison']=('The data is skewed to the left')

# What happens to the mean population? What happens to the median? if we remove the 50 most populous cities

#most_populous=df['population'].nlargest(50)# we are selecting the 50 most populous cities according to the dataset
#df.drop(most_populous.index).describe()[['population']].loc[['mean','50%']]# this seems to be the most efficient

#df.loc[50:, 'population'].describe()[['mean','50%']]# we are getting rid of the 50 most populous cities according to the dataset and calculating the mean and the median

#What is the northernmost city, and where does it rank?

#df.loc[df['latitude'].nlargest(1).index, ['city','state','rank']]
#df.loc[df['latitude']==df['latitude'].max(),['city','state','rank']]# these two codes do the same thing just with a different approach

#Which state has the largest number of cities on this list?

df.loc[df['state'].value_counts().head(1), 'state']
# Out:
# 212    Washington
# Name: state, dtype: object
