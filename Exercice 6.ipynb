# %%
import pandas as pd
import numpy as np

df=pd.read_csv('/content/taxi-passenger-count.csv',header=None).squeeze()
df.value_counts(normalize=True) [[1,6]]
# Out:
# 0
# 1    0.720772
# 6    0.036904
# Name: proportion, dtype: float64
