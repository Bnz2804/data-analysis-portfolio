# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
df=pd.read_csv('https://api.blockchain.info/charts/market-price?format=csv',
               header=None,
               names=['date', 'value'])
df.tail(1)[['value']]#retrieve the data at the top of the dataframe
#print (df.loc[df['value']==df['value'].min(), ['date', 'value']])
#print (df.loc[df['value']==df['value'].max(), ['date', 'value']])
#df.set_index('date').loc[df.set_index('date')['value'].idxmin(), 'value']
df.set_index('date').idxmin()
# Out:
# value    2024-01-23 00:00:00
# dtype: object
