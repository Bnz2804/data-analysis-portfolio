# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
df=pd.read_csv('/content/drive/MyDrive/Irwin data analysis portfolio/data/data/nyc-parking-violations-2020.csv',
usecols=['Date First Observed', 'Plate ID', 'Registration State','Issue Date', 'Vehicle Make', 'Street Name', 'Vehicle Color'])

df=df.set_index('Issue Date')

#df.loc['01/02/2020 12:00:00 AM', 'Vehicle Make'].value_counts().head(3)# what three makes were most frequently ticketed on january 2, 2020

#df.loc['06/01/2020 12:00:00 AM', 'Street Name'].value_counts().head(5)# what are the five streets on which cars got the most tickets on june 1, 2020

df=df.reset_index().set_index('Vehicle Color')

df.loc[['RED','BLUE'], 'Vehicle Make'].value_counts().head(1)# the most common make of vehicles that were either red or blue
# Out:
# Vehicle Make
# HONDA    39353
# Name: count, dtype: int64
